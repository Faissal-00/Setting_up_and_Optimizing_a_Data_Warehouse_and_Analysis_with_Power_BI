# %% [markdown]
# # Step 1: Loading data

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('ecommerce-data.csv', encoding = 'utf-8')
df.head()
# Out:
#          Date         ProductName  ProductCategory ProductSubCategory
# 0  2023-09-14           Nathaniel      Electronics             Camera  \
# 1  2023-02-11  NonExistentProduct      Electronics             Mobile
# 2  2021-11-12              Angela  InvalidCategory     Action Figures
# 3  11-15-2021                 Amy    Home & Garden              Decor
# 4  2023-04-22           Nathaniel      Electronics             Camera
#
#   ProductPrice     CustomerName                   CustomerEmail
# 0         0.01    Colleen Kelly           maryhurst@example.org  \
# 1       847.43      Joel Wright     sandersvictoria@example.org
# 2       386.57    Thomas Sawyer             ospence@example.net
# 3       364.01    Tyler Gardner  christopherjohnson@example.com
# 4       652.35  Meagan Peterson             epowell@example.net
#
#                                  CustomerAddress           CustomerPhone
# 0  354 Mcdowell Turnpike, Port Charles, CT 95318       908.610.2711x8507  \
# ...

# %%
df.shape
# Out:
# (5010, 22)

# %%
df.columns
# Out:
# Index(['Date', 'ProductName', 'ProductCategory', 'ProductSubCategory',
#        'ProductPrice', 'CustomerName', 'CustomerEmail', 'CustomerAddress',
#        'CustomerPhone', 'CustomerSegment', 'SupplierName', 'SupplierLocation',
#        'SupplierContact', 'ShipperName', 'ShippingMethod', 'QuantitySold',
#        'TotalAmount', 'DiscountAmount', 'NetAmount', 'StockReceived',
#        'StockSold', 'StockOnHand'],
#       dtype='object')

# %%
# # Rename the columns
# df.rename(columns={'Date_Order': 'DateOrder'}, inplace=True)
# df.rename(columns={'Location_warehouse': 'LocationWarehouse'}, inplace=True)
# df.rename(columns={'Location_Supplier': 'LocationSupplier'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'ProductName', 'ProductCategory', 'ProductSubCategory',
#        'ProductPrice', 'CustomerName', 'CustomerEmail', 'CustomerAddress',
#        'CustomerPhone', 'CustomerSegment', 'SupplierName', 'SupplierLocation',
#        'SupplierContact', 'ShipperName', 'ShippingMethod', 'QuantitySold',
#        'TotalAmount', 'DiscountAmount', 'NetAmount', 'StockReceived',
#        'StockSold', 'StockOnHand'],
#       dtype='object')

# %%
df['CustomerAddress'] = df['CustomerAddress'].str.replace(',', '-')
# Replace both commas and 'and' with hyphens in the 'SupplierName' column
df['SupplierName'] = df['SupplierName'].str.replace(r',| and ', '-', regex=True)

# %%
columns=df.columns.tolist()
df[columns[10:]]
# Out:
#                   SupplierName SupplierLocation        SupplierContact
# 0     Rodriguez- Winters-Perez       Irwinhaven             6538306661  \
# 1               Lawson-Wilkins  Calderonchester                    NaN
# 2                   Lee-Miller  South Emilyview        +1-588-750-7646
# 3                  Soto-Rivera      West Denise      805-650-6257x5876
# 4     Rodriguez- Winters-Perez       Irwinhaven             6538306661
# ...                        ...              ...                    ...
# 5005            Roman-Chambers    Dennischester  001-324-909-1637x2831
# 5006            Roman-Chambers    Dennischester  001-324-909-1637x2831
# 5007            Roman-Chambers    Dennischester  001-324-909-1637x2831
# 5008            Roman-Chambers    Dennischester  001-324-909-1637x2831
# 5009            Roman-Chambers    Dennischester  001-324-909-1637x2831
#
#      ShipperName ShippingMethod  QuantitySold  TotalAmount  DiscountAmount
# ...

# %% [markdown]
# # Step 2: Shuffle and Split the Data

# %%
# Shuffle the data
df_shuffled = df.sample(frac=1, random_state=42)

# Calculate the number of rows for each destination
total_rows = df_shuffled.shape[0]
json_rows = int(0.5 * total_rows)
csv_rows = total_rows - json_rows

# Split the data into JSON and CSV parts
df_json = df_shuffled.iloc[:json_rows]
df_csv = df_shuffled.iloc[json_rows:]

# %% [markdown]
# # Save the JSON and CSV Data

# %%
# Save the splits to their respective destinations (JSON, database, and CSV)
df_json.to_json('data.json', orient='records')
df_csv.to_csv('data.csv', index=False, encoding = 'utf-8')
