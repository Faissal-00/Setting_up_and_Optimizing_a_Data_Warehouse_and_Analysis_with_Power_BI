# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('ecommerce-data.csv',encoding='UTF-8')
df.head()
# Out:
#          Date         ProductName  ProductCategory ProductSubCategory
# 0  2023-09-14           Nathaniel      Electronics             Camera  \
# 1  2023-02-11  NonExistentProduct      Electronics             Mobile
# 2  2021-11-12              Angela  InvalidCategory     Action Figures
# 3  11-15-2021                 Amy    Home & Garden              Decor
# 4  2023-04-22           Nathaniel      Electronics             Camera
#
#   ProductPrice     CustomerName                   CustomerEmail
# 0         0.01    Colleen Kelly           maryhurst@example.org  \
# 1       847.43      Joel Wright     sandersvictoria@example.org
# 2       386.57    Thomas Sawyer             ospence@example.net
# 3       364.01    Tyler Gardner  christopherjohnson@example.com
# 4       652.35  Meagan Peterson             epowell@example.net
#
#                                  CustomerAddress           CustomerPhone
# 0  354 Mcdowell Turnpike, Port Charles, CT 95318       908.610.2711x8507  \
# ...

# %%
df.describe()
# Out:
#        QuantitySold   TotalAmount  DiscountAmount     NetAmount
# count   5010.000000   5010.000000     5010.000000   5010.000000  \
# mean      50.827146  28851.529621       86.425236  28765.104385
# std       28.523303  23139.578225       70.574899  23112.635714
# min        1.000000     46.230000        0.010000     33.600000
# 25%       26.000000   8864.130000       25.685000   8774.435000
# 50%       50.000000  23546.135000       69.345000  23424.750000
# 75%       76.000000  42985.950000      129.277500  42886.600000
# max      100.000000  99513.000000      298.110000  99276.950000
#
#        StockReceived    StockSold  StockOnHand
# count    5010.000000  5010.000000  5010.000000
# mean      277.074052   139.116966   137.957086
# std       130.330697   111.016370   110.360693
# min        50.000000     1.000000     0.000000
# 25%       164.000000    49.000000    49.000000
# 50%       279.000000   109.000000   107.000000
# 75%       393.000000   209.000000   206.000000
# ...

# %%
df.columns
# Out:
# Index(['Date', 'ProductName', 'ProductCategory', 'ProductSubCategory',
#        'ProductPrice', 'CustomerName', 'CustomerEmail', 'CustomerAddress',
#        'CustomerPhone', 'CustomerSegment', 'SupplierName', 'SupplierLocation',
#        'SupplierContact', 'ShipperName', 'ShippingMethod', 'QuantitySold',
#        'TotalAmount', 'DiscountAmount', 'NetAmount', 'StockReceived',
#        'StockSold', 'StockOnHand'],
#       dtype='object')

# %%
print(df.isnull().sum(axis=0))
# Out:
# Date                    0
# ProductName             0
# ProductCategory         0
# ProductSubCategory      0
# ProductPrice            0
# CustomerName            0
# CustomerEmail         507
# CustomerAddress         0
# CustomerPhone           0
# CustomerSegment         0
# SupplierName            0
# SupplierLocation        0
# SupplierContact       484
# ShipperName             0
# ShippingMethod          0
# QuantitySold            0
# TotalAmount             0
# DiscountAmount          0
# NetAmount               0
# StockReceived           0
# StockSold               0
# StockOnHand             0
# dtype: int64

# %%
duplicates = df[df.duplicated(keep='first')].shape[0] 
duplicates
# Out:
# 10

# %%
columns=df.columns.tolist()
df[columns[:10]]
# Out:
#             Date         ProductName  ProductCategory ProductSubCategory
# 0     2023-09-14           Nathaniel      Electronics             Camera  \
# 1     2023-02-11  NonExistentProduct      Electronics             Mobile
# 2     2021-11-12              Angela  InvalidCategory     Action Figures
# 3     11-15-2021                 Amy    Home & Garden              Decor
# 4     2023-04-22           Nathaniel      Electronics             Camera
# ...          ...                 ...              ...                ...
# 5005  2023-08-24              Angela             Toys     Action Figures
# 5006  2023-08-24              Angela             Toys     Action Figures
# 5007  2023-08-24              Angela             Toys     Action Figures
# 5008  2023-08-24              Angela             Toys     Action Figures
# 5009  2023-08-24              Angela             Toys     Action Figures
#
#      ProductPrice     CustomerName                   CustomerEmail
# ...

# %%
columns=df.columns.tolist()
df[columns[10:]].head(20)
# Out:
#                     SupplierName  SupplierLocation        SupplierContact
# 0   Rodriguez, Winters and Perez        Irwinhaven             6538306661  \
# 1                 Lawson-Wilkins   Calderonchester                    NaN
# 2                     Lee-Miller   South Emilyview        +1-588-750-7646
# 3                    Soto-Rivera       West Denise      805-650-6257x5876
# 4   Rodriguez, Winters and Perez        Irwinhaven             6538306661
# 5                    Soto-Rivera       West Denise      805-650-6257x5876
# 6                    Soto-Rivera       West Denise      805-650-6257x5876
# 7                 Campos-Murillo        Lawsontown           822-222-4939
# 8       Wagner, Jackson and Holt    Port Sarahview   +1-362-752-2777x1817
# 9                 White and Sons        West Scott           288-572-7043
# 10                  Brown-Miller          Seanfort          (502)758-2166
# 11       Colon, Palmer and Welch      Antonioshire       230-757-6575x898
# ...

# %%
# Find records with 'NonExistentProduct' in ProductName
non_existent_product = df[df['ProductName'] == 'NonExistentProduct']
non_existent_product
# Out:
#             Date         ProductName ProductCategory ProductSubCategory
# 1     2023-02-11  NonExistentProduct     Electronics             Mobile  \
# 5     2022-12-08  NonExistentProduct     Electronics             Mobile
# 7     2023-07-19  NonExistentProduct     Electronics             Camera
# 9     2023-07-15  NonExistentProduct   Home & Garden              Decor
# 14    2022-08-30  NonExistentProduct           Books            Fiction
# ...          ...                 ...             ...                ...
# 4965  2021-11-22  NonExistentProduct     Electronics         Headphones
# 4971  2023-02-07  NonExistentProduct   Home & Garden              Decor
# 4980  2023-02-01  NonExistentProduct     Electronics         Headphones
# 4981  2022-07-07  NonExistentProduct     Electronics         Headphones
# 4995  2023-05-16  NonExistentProduct           Books        Non-fiction
#
#       ProductPrice      CustomerName                CustomerEmail
# ...

# %%
# Find records with 'InvalidCategory' in ProductCategory
invalid_category = df[df['ProductCategory'] == 'InvalidCategory']
invalid_category
# Out:
#             Date ProductName  ProductCategory ProductSubCategory
# 2     2021-11-12      Angela  InvalidCategory     Action Figures  \
# 12    2023-09-19   Elizabeth  InvalidCategory              Shirt
# 22    2023-05-17        Fred  InvalidCategory           Academic
# 34    2022-10-04      Martha  InvalidCategory            Fiction
# 38    2022-04-10      Angela  InvalidCategory     Action Figures
# ...          ...         ...              ...                ...
# 4970  2022-04-24       Wanda  InvalidCategory        Educational
# 4979  2022-04-30       Tammy  InvalidCategory          Furniture
# 4982  2021-11-24       Tammy  InvalidCategory          Furniture
# 4988  2022-11-04       Wanda  InvalidCategory        Educational
# 4993  2021-11-15      Angela  InvalidCategory     Action Figures
#
#       ProductPrice      CustomerName              CustomerEmail
# 2           386.57     Thomas Sawyer        ospence@example.net  \
# ...

# %%
# Find records with 'InvalidPrice' in ProductPrice
invalid_price = df[df['ProductPrice'] == 'InvalidPrice']
invalid_price
# Out:
#             Date         ProductName  ProductCategory ProductSubCategory
# 23    2022-04-19  NonExistentProduct    Home & Garden              Decor  \
# 33    2022-03-25                 Amy    Home & Garden              Decor
# 51    2022-11-05             Michael  InvalidCategory              Dolls
# 54    05-03-2023             Shannon    Home & Garden    Gardening Tools
# 67    01-14-2023             Michael             Toys              Dolls
# ...          ...                 ...              ...                ...
# 4944  2023-08-13              Pamela      Electronics         Headphones
# 4956  2022-07-07                 Amy    Home & Garden              Decor
# 4966  2022-05-10             Cynthia      Electronics         Headphones
# 4970  2022-04-24               Wanda  InvalidCategory        Educational
# 4981  2022-07-07  NonExistentProduct      Electronics         Headphones
#
#       ProductPrice       CustomerName              CustomerEmail
# ...

# %%
pn = df['ProductName'].unique()
pn
# Out:
# array(['Nathaniel', 'NonExistentProduct', 'Angela', 'Amy', 'Justin',
#        'Shannon', 'Martha', 'Elizabeth', 'Jamie', 'Robert', 'Shawn',
#        'Anthony', 'Pamela', 'Fred', 'Wanda', 'Cynthia', 'Marvin', 'Katie',
#        'Tammy', 'Michael', 'Kristine'], dtype=object)

# %%
pc = df['ProductCategory'].unique()
pc
# Out:
# array(['Electronics', 'InvalidCategory', 'Home & Garden', 'Books',
#        'Clothing', 'Toys'], dtype=object)

# %%
ps = df['ProductSubCategory'].unique()
ps
# Out:
# array(['Camera', 'Mobile', 'Action Figures', 'Decor', 'Headphones',
#        'Gardening Tools', 'Fiction', 'Shirt', 'Academic', 'Educational',
#        'Non-fiction', 'Dolls', 'Furniture'], dtype=object)

# %%
sn = df['SupplierName'].unique()
sn
# Out:
# array(['Rodriguez, Winters and Perez', 'Lawson-Wilkins', 'Lee-Miller',
#        'Soto-Rivera', 'Campos-Murillo', 'Wagner, Jackson and Holt',
#        'White and Sons', 'Brown-Miller', 'Colon, Palmer and Welch',
#        'Mack, Wright and Mclaughlin', 'Roman-Chambers',
#        'Mathis, Olson and Ryan', 'Peck Group', 'Ramirez, Hicks and Lara',
#        'Smith PLC', 'Gilbert, Miller and Lee', 'Higgins and Sons',
#        'King-Rodriguez', 'Randall-Ballard', 'Thornton, Jackson and Gray'],
#       dtype=object)

# %%
sl = df['SupplierLocation'].unique()
sl
# Out:
# array(['Irwinhaven', 'Calderonchester', 'South Emilyview', 'West Denise',
#        'Lawsontown', 'Port Sarahview', 'West Scott', 'Seanfort',
#        'Antonioshire', 'Alexandrachester', 'Dennischester', 'Herreraland',
#        'West Lindafurt', 'Dustinmouth', 'Lake Candiceton',
#        'Lake Juanland', 'West Johnbury', 'South Lindatown', 'Popeport',
#        'Leslieville'], dtype=object)

# %%
shn = df['ShipperName'].unique()
shn
# Out:
# array(['and Sons', 'PLC', 'LLC', 'Ltd', 'Inc', 'Group'], dtype=object)

# %%
shm = df['ShippingMethod'].unique()
shm
# Out:
# array(['Ground', 'Air', 'Sea'], dtype=object)

# %%
# List the names of the four columns you want to use for checking duplicates
columns_to_check = ['QuantitySold', 'TotalAmount', 'DiscountAmount', 'NetAmount']

# Use the 'duplicated' method on the specified columns
duplicates = df.duplicated(subset=columns_to_check, keep='first')  # 'keep' can be 'first', 'last', or False

# The 'duplicates' Series will have True for rows that are duplicates based on the specified columns.

# If you want to see the rows that are duplicates, you can filter the DataFrame:
duplicate_rows = df[duplicates]

duplicate_rows
# Out:
#             Date ProductName ProductCategory ProductSubCategory ProductPrice
# 5000  2023-08-24      Angela            Toys     Action Figures       386.57  \
# 5001  2023-08-24      Angela            Toys     Action Figures       386.57
# 5002  2023-08-24      Angela            Toys     Action Figures       386.57
# 5003  2023-08-24      Angela            Toys     Action Figures       386.57
# 5004  2023-08-24      Angela            Toys     Action Figures       386.57
# 5005  2023-08-24      Angela            Toys     Action Figures       386.57
# 5006  2023-08-24      Angela            Toys     Action Figures       386.57
# 5007  2023-08-24      Angela            Toys     Action Figures       386.57
# 5008  2023-08-24      Angela            Toys     Action Figures       386.57
# 5009  2023-08-24      Angela            Toys     Action Figures       386.57
#
#        CustomerName            CustomerEmail
# 5000  Bradley Smith  garciashawn@example.com  \
# ...

# %%
# uni = df.groupby('ProductID')['Price'].unique()
# uni

# %%
# uni = df.groupby('WarehouseID')['InventoryID'].unique()
# uni

# %%
# uni = df.groupby('WarehouseID')['InventoryID'].unique()
# uni

# %%
# name = df[df['SupplierContact'] == 'NaN']
# name

# %%
# duplicates = df[df['Location'].duplicated(keep=False)]

# duplicate_names = duplicates['Location'].unique()

# duplicates

# %%
# aa=df['UserSegment'].unique()
# aa

# %%
# zero = df[df['Price'] == 0].shape
# zero

# %%
# zero = df[df['Quantity'] == 0]
# zero

# %%
# lap = df[df['Product Name'] == 'LaptopPro']
# lap

# %%
# # Sort the DataFrame by the 'Name' column
# df_sorted = df.sort_values(by='Name')
# df_sorted

# %%
# duplicates = df[df['Name'].duplicated(keep=False)]

# duplicate_names = duplicates['Name'].unique()

# filtered_rows = df[df['Name'].isin(duplicate_names)]

# filtered_rows

# %%
# import matplotlib.pyplot as plt
# # Replace 'Age' with the name of the column you want to check for outliers
# column_name = 'Price'

# # Create a scatter plot to visualize outliers
# plt.figure(figsize=(8, 6))
# plt.scatter(range(len(df[column_name])), df[column_name])
# plt.title(f'Scatter Plot of {column_name}')
# plt.xlabel('Index')
# plt.ylabel(column_name)
# plt.show()

# %%
# filtered_rows = df[df['Age'] < 100 ]
# filtered_rows

# %%
# columns_with_nan = df.columns[df.isnull().any()]

# print("Columns with NaN values:")
# print(columns_with_nan)

# %%
# import pandas as pd

# # Assuming you have a DataFrame named 'df'
# # Replace 'df' with your actual DataFrame name

# # Iterate through each column
# for column in df.columns:
#     # Check if any value in the column contains a hyphen
#     if df[column].astype(str).str.contains('-').any():
#         print(f"Column '{column}' contains values with a hyphen.")

# %%
# column_values = df['FullAddress']

# print(column_values)
